# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('Country-data.csv')
data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
data = data.drop('country', axis=1)
col = data.columns

fig = plt.figure()
ax = fig.add_subplot(111)
plt.rcParams["figure.figsize"] = (20,10)
cax = ax.matshow(data.corr())
fig.colorbar(cax)
ax.set_xticks(np.arange(len(col)))
ax.set_xticklabels(col, rotation=90)
ax.set_yticks(np.arange(len(col)))
ax.set_yticklabels(col)
# Out:
# [Text(0, 0, 'child_mort'),
#  Text(0, 0, 'exports'),
#  Text(0, 0, 'health'),
#  Text(0, 0, 'imports'),
#  Text(0, 0, 'income'),
#  Text(0, 0, 'inflation'),
#  Text(0, 0, 'life_expec'),
#  Text(0, 0, 'total_fer'),
#  Text(0, 0, 'gdpp')]

# %%
print(data.iloc[1,0])
# Out:
# Albania

# %%
print(data.loc[1,'country'])
# Out:
# Albania

# %%
data = data.set_index('country')

# %%
data.head()
# Out:
#                      child_mort  exports  health  imports  income  inflation  \
# country
# Afghanistan                90.2     10.0    7.58     44.9    1610       9.44
# Albania                    16.6     28.0    6.55     48.6    9930       4.49
# Algeria                    27.3     38.4    4.17     31.4   12900      16.10
# Angola                    119.0     62.3    2.85     42.9    5900      22.40
# Antigua and Barbuda        10.3     45.5    6.03     58.9   19100       1.44
#
#                      life_expec  total_fer   gdpp
# country
# Afghanistan                56.2       5.82    553
# Albania                    76.3       1.65   4090
# Algeria                    76.5       2.89   4460
# Angola                     60.1       6.16   3530
# Antigua and Barbuda        76.8       2.13  12200

# %%
data.loc['Albania']
# Out:
# child_mort      16.60
# exports         28.00
# health           6.55
# imports         48.60
# income        9930.00
# inflation        4.49
# life_expec      76.30
# total_fer        1.65
# gdpp          4090.00
# Name: Albania, dtype: float64

# %%
data.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Yemen', 'Zambia'],
#       dtype='object', name='country', length=167)

# %%
data['country2'] = data.index

# %%
data.head()
# Out:
#                      child_mort  exports  health  imports  income  inflation  \
# country
# Afghanistan                90.2     10.0    7.58     44.9    1610       9.44
# Albania                    16.6     28.0    6.55     48.6    9930       4.49
# Algeria                    27.3     38.4    4.17     31.4   12900      16.10
# Angola                    119.0     62.3    2.85     42.9    5900      22.40
# Antigua and Barbuda        10.3     45.5    6.03     58.9   19100       1.44
#
#                      life_expec  total_fer   gdpp             country2
# country
# Afghanistan                56.2       5.82    553          Afghanistan
# Albania                    76.3       1.65   4090              Albania
# Algeria                    76.5       2.89   4460              Algeria
# Angola                     60.1       6.16   3530               Angola
# Antigua and Barbuda        76.8       2.13  12200  Antigua and Barbuda

# %%
data = data.reset_index(level=0, drop=False)

# %%
data.drop('country2', axis=1, inplace = True)

# %%
data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
print(data.index.name)
# Out:
# country

# %%
data.drop_duplicates('gdpp')
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 158       United Kingdom         5.2     28.2    9.64     30.8   36200
# 159        United States         7.3     12.4   17.90     15.8   49400
# 160              Uruguay        10.6     26.3    8.35     25.4   17100
# 161           Uzbekistan        36.3     31.7    5.81     28.5    4240
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
data = data.set_index('country')
data.loc['AAAAA'] = data.loc['Albania']

# %%
data.loc['AAAAA']
# Out:
# child_mort      16.60
# exports         28.00
# health           6.55
# imports         48.60
# income        9930.00
# inflation        4.49
# life_expec      76.30
# total_fer        1.65
# gdpp          4090.00
# Name: AAAAA, dtype: float64

# %%
data.rename(columns={'child_mort': 'child_mort2'}, inplace=True)

# %%
data.head()
# Out:
#                      child_mort2  exports  health  imports   income  \
# country
# Afghanistan                 90.2     10.0    7.58     44.9   1610.0
# Albania                     16.6     28.0    6.55     48.6   9930.0
# Algeria                     27.3     38.4    4.17     31.4  12900.0
# Angola                     119.0     62.3    2.85     42.9   5900.0
# Antigua and Barbuda         10.3     45.5    6.03     58.9  19100.0
#
#                      inflation  life_expec  total_fer     gdpp
# country
# Afghanistan               9.44        56.2       5.82    553.0
# Albania                   4.49        76.3       1.65   4090.0
# Algeria                  16.10        76.5       2.89   4460.0
# Angola                   22.40        60.1       6.16   3530.0
# Antigua and Barbuda       1.44        76.8       2.13  12200.0
